# %%
import pandas as pd
import json

# %%
vacant_buildings = 'https://data.cityofchicago.org/resource/kc9i-wq85.json'

# %%
abandon = pd.read_json(vacant_buildings)

# %%
abandon
# Out:
#      collection_costs_or_attorney_fees  court_cost  current_amount_due  \
# 0                                    0         0.0                 NaN
# 1                                    0         0.0                 NaN
# 2                                    0         0.0                 NaN
# 3                                    0         0.0                 NaN
# 4                                    0         0.0                 NaN
# 5                                    0         0.0                 NaN
# 6                                    0         0.0                 NaN
# 7                                    0         0.0                 NaN
# 8                                    0         0.0                 NaN
# 9                                    0         0.0                 NaN
# 10                                   0         0.0                 NaN
# 11                                   0         0.0                 NaN
# ...

# %%
abandon['entity_or_person_s_'].unique()
# Out:
# array(['NATIONWIDE REO LLC, ', 'WELLS FARGO BANK NA, ',
#        'U S BANK AND TRUST, ', 'TCF NATL BANK, ',
#        'DEUTSCHE BANK NATL TRUST, ', 'REPUBLIC BANK OF CHICAGO, ',
#        'NORTH STAR TRUST COMPANY, ', 'WELLS FARGO BANK N A, ',
#        'DEUTSCHE BANK, ', 'CITIBANK, ', 'BANK OF AMERICA, ',
#        'FEDERAL NATL MORTGAGE ASSN, ', 'CITI MORTGAGE, ',
#        'CITIFINANCIAL SERVICES INC, ',
#        'GREEN POINT MORTGAGE FUNDING INC, ', 'BANK NY MELLON, ',
#        'LITTON LOAN SERVICING, ', 'QUANTIM SERVICING CORPORATION, ',
#        'REO PARTNERS LLC, ', 'INDYMAC FEDERAL BANK, ',
#        'JP MORGAN CHASE, ', 'OCWEN LOAN SERVICES LLC, ',
#        'SMITH ROTHCHILD FINANCIAL CO, ',
#        'NATIONAL ASSET MANAGEMENT GROUP LLC, ', 'CITI MORTGAGE INC, ',
#        'AURORA LOAN SERV LLC, ', 'WELLS FARGO, ',
#        'DEUTSCHE BANK NATIONAL TRUST, ', 'FRANKLIN CREDIT MANAGEMENT, ',
#        'QUANTUM SERVICING CORPORATION, ', 'JPMC SPECIALITY MORT, ',
# ...

# %%
len(abandon['property_address'].unique())*20
# Out:
# 3800

# %%
abandon.to_csv('raw_data/abandon.csv')
