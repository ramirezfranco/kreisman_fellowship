# %%
import pandas as pd
import json
from sodapy import Socrata

# %%
client = Socrata("data.cityofchicago.org", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client.get("kc9i-wq85", limit=100000)

# %%
results_df = pd.DataFrame.from_records(results)

# %%
len(results_df)
# Out:
# 21435

# %%
addresses = list(results_df['property_address'].unique())

# %%
results_df[-200:]
# Out:
#       collection_costs_or_attorney_fees court_cost current_amount_due  \
# 21235                                 0          0                NaN
# 21236                                 0          0                NaN
# 21237                                 0          0                NaN
# 21238                                 0          0                NaN
# 21239                                 0          0                NaN
# 21240                                 0          0                NaN
# 21241                                 0          0                NaN
# 21242                                 0          0                NaN
# 21243                                 0          0                NaN
# 21244                                 0          0                NaN
# 21245                                 0          0                NaN
# 21246                                 0          0                NaN
# ...

# %%
address_year = []
for address in addresses:
    min_year= min([int(date[:4]) for date in results_df[results_df['property_address']==address]['issued_date']])
    address_year.append([address, min_year])

# %%
key='AIzaSyBK-jnnMHq4Spzq5MRNAwU_eEbRykKpQ3c'

# %%
import googlemaps

# %%
client = googlemaps.Client(key=key)

# %%
#complete_data = []

# %%
for building in address_year:
    try:
        info = client.geocode(building[0]+'chicago')[0]
        complete_data.append([building[0], building[1], info['geometry']['location']['lat'], info['geometry']['location']['lng']])
    except IndexError:
        pass

# %%
len(complete_data)
# Out:
# 2380

# %%
abandoned_buildings = pd.DataFrame(complete_data, columns=['address', 'year', 'lat', 'long'])
abandoned_buildings.to_csv('abandoned_buildings.csv')

# %%
abandoned_buildings.groupby('year').count()
# Out:
#       address  lat  long
# year
# 2001        4    4     4
# 2004        1    1     1
# 2006        1    1     1
# 2011      403  403   403
# 2012      315  315   315
# 2013      341  341   341
# 2014      426  426   426
# 2015      367  367   367
# 2016      219  219   219
# 2017      193  193   193
# 2018       80   80    80
# 2019       30   30    30

# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-136-a62d01c1d62e> in <module>
# ----> 1 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'
